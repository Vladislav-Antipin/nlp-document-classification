# %% [markdown]
# # NLP Project
#
# ANTIPIN Vladislav, OUNDJIAN Milos

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import re
from pathlib import Path
import string
import pickle

from functools import partial

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression  # TODO we can also use this
from sklearn.model_selection import StratifiedKFold, cross_validate, cross_val_predict
from sklearn.metrics import classification_report

from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %%
from rital.data import (
    load_presidents,
    load_presidents_unseen,
    load_movies,
    load_movies_unseen,
)
from rital.preprocessing import preprocess

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Data Loading

# %%
x_presidents, y_presidents = load_presidents()
x_presidents_unseen = load_presidents_unseen()
x_movies, y_movies = load_movies()
x_movies_unseen = load_movies_unseen()

# %% [markdown]
# ## Basic TF-IDF Classifier

# %%
# Data
# Switch this between presidents and movies
X_train = x_movies
y_train = y_movies

# TF-IDF + SVM pipeline
model = Pipeline(
    [
        ("tfidf", TfidfVectorizer(preprocessor=preprocess)),
        ("classifier", LinearSVC()),
    ]
)

cv = StratifiedKFold(5, shuffle=True, random_state=42)

scores = cross_validate(
    model, X_train, y_train, cv=cv, scoring=["accuracy", "f1", "precision", "recall"]
)

for metric, values in scores.items():
    if "test" in metric:
        print(f"{metric}: {values.mean():.3f}")


y_pred = cross_val_predict(model, X_train, y_train, cv=cv)

print(classification_report(y_train, y_pred))
# Out:
# test_accuracy: 0.858
# test_f1: 0.860
# test_precision: 0.847
# test_recall: 0.873
#               precision    recall  f1-score   support
#
#            0       0.87      0.84      0.86      1000
#            1       0.85      0.87      0.86      1000
#
#     accuracy                           0.86      2000
#    macro avg       0.86      0.86      0.86      2000
# weighted avg       0.86      0.86      0.86      2000

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# ~ 1m runtime

# %%
# Data
X_train = x_movies
y_train = y_movies

# CV splitter
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Pipeline
model = Pipeline(
    [
        ("tfidf", TfidfVectorizer(preprocessor=preprocess)),
        ("classifier", LinearSVC()),
    ]
)

# Hyperparameter grid
param_grid = {
    "tfidf__ngram_range": [(1, 1), (1, 2)],
    "tfidf__min_df": [1, 2, 5],
    "tfidf__max_df": [0.9, 1.0],
    "tfidf__sublinear_tf": [False, True],
    "classifier__C": [0.01, 0.1, 1, 10],
}

# Grid search
grid = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=cv,
    scoring="f1",  # or "accuracy"
    n_jobs=-1,
    verbose=3,
)

grid.fit(X_train, y_train)

print(f"Best parameters: {grid.best_params_}")
print(f"Best CV score: {grid.best_score_}")

best_model = grid.best_estimator_

y_pred = cross_val_predict(best_model, X_train, y_train, cv=cv)

print("Classification report:")
print(classification_report(y_train, y_pred))
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV 1/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1), tfidf__sublinear_tf=False;, score=0.800 total time=   1.0s
# [CV 2/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1), tfidf__sublinear_tf=False;, score=0.789 total time=   1.1s
# [CV 1/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1), tfidf__sublinear_tf=True;, score=0.832 total time=   1.0s
# [CV 3/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1), tfidf__sublinear_tf=False;, score=0.827 total time=   1.1s
# [CV 5/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1), tfidf__sublinear_tf=False;, score=0.832 total time=   1.1s
# [CV 2/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1), tfidf__sublinear_tf=True;, score=0.833 total time=   1.2s
# [CV 3/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1), tfidf__sublinear_tf=True;, score=0.864 total time=   1.2s
# [CV 4/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1), tfidf__sublinear_tf=False;, score=0.749 total time=   1.3s
# [CV 4/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1), tfidf__sublinear_tf=True;, score=0.779 total time=   1.2s
# [CV 5/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 1), tfidf__sublinear_tf=True;, score=0.860 total time=   1.1s
# [CV 3/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=False;, score=0.821 total time=   3.4s
# [CV 1/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=False;, score=0.821 total time=   3.6s
# [CV 4/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=False;, score=0.776 total time=   3.7s
# [CV 2/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=False;, score=0.802 total time=   3.8s
# [CV 1/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.847 total time=   3.8s
# [CV 3/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.851 total time=   3.7s
# [CV 5/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=False;, score=0.859 total time=   3.9s
# [CV 4/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.791 total time=   3.8s
# [CV 2/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.854 total time=   4.0s
# [CV 5/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=1, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.880 total time=   3.8s
# [CV 1/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1), tfidf__sublinear_tf=False;, score=0.797 total time=   1.3s
# [CV 2/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1), tfidf__sublinear_tf=False;, score=0.791 total time=   1.3s
# [CV 4/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1), tfidf__sublinear_tf=False;, score=0.749 total time=   1.1s
# [CV 3/5] END classifier__C=0.01, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 1), tfidf__sublinear_tf=False;, score=0.823 total time=   1.2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[174], line 35
#      25 # Grid search
#      26 grid = GridSearchCV(
#      27     estimator=model,
#      28     param_grid=param_grid,
#    (...)     32     verbose=3,
#      33 )
# ---> 35 grid.fit(X_train, y_train)
#      37 print(f"Best parameters: {grid.best_params_}")
#      38 print(f"Best CV score: {grid.best_score_}")
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1053, in BaseSearchCV.fit(self, X, y, **params)
#    1047     results = self._format_results(
#    1048         all_candidate_params, n_splits, all_out, all_more_results
#    1049     )
#    1051     return results
# -> 1053 self._run_search(evaluate_candidates)
#    1055 # multimetric is determined here because in the case of a callable
#    1056 # self.scoring the return type is only known after calling
#    1057 first_test_score = all_out[0]["test_scores"]
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1612, in GridSearchCV._run_search(self, evaluate_candidates)
#    1610 def _run_search(self, evaluate_candidates):
#    1611     """Search all candidates in param_grid"""
# -> 1612     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/model_selection/_search.py:999, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     991 if self.verbose > 0:
#     992     print(
#     993         "Fitting {0} folds for each of {1} candidates,"
#     994         " totalling {2} fits".format(
#     995             n_splits, n_candidates, n_candidates * n_splits
#     996         )
#     997     )
# --> 999 out = parallel(
#    1000     delayed(_fit_and_score)(
#    1001         clone(base_estimator),
#    1002         X,
#    1003         y,
#    1004         train=train,
#    1005         test=test,
#    1006         parameters=parameters,
#    1007         split_progress=(split_idx, n_splits),
#    1008         candidate_progress=(cand_idx, n_candidates),
#    1009         **fit_and_score_kwargs,
#    1010     )
#    1011     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#    1012         enumerate(candidate_params),
#    1013         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#    1014     )
#    1015 )
#    1017 if len(out) < 1:
#    1018     raise ValueError(
#    1019         "No fits were performed. "
#    1020         "Was the CV iterator empty? "
#    1021         "Were there no candidates?"
#    1022     )
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %% [markdown]
# ~ 1m40s runtime

# %%
# Data
X_train = x_presidents
y_train = y_presidents

# CV splitter
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Pipeline
model = Pipeline(
    [
        ("tfidf", TfidfVectorizer(preprocessor=preprocess)),
        ("classifier", LinearSVC()),
    ]
)

# Hyperparameter grid
param_grid = {
    "tfidf__ngram_range": [(1, 1), (1, 2)],
    "tfidf__min_df": [1, 2, 5],
    "tfidf__max_df": [0.9, 1.0],
    "tfidf__sublinear_tf": [False, True],
    "classifier__C": [0.01, 0.1, 1, 10],
}

# Grid search
grid = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=cv,
    scoring="f1",  # or "accuracy"
    n_jobs=-1,
    verbose=1,
)

grid.fit(X_train, y_train)

print(f"Best parameters: {grid.best_params_}")
print(f"Best CV score: {grid.best_score_}")

best_model = grid.best_estimator_

y_pred = cross_val_predict(best_model, X_train, y_train, cv=cv)

print("Classification report:")
print(classification_report(y_train, y_pred))
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# Best parameters: {'classifier__C': 1, 'tfidf__max_df': 0.9, 'tfidf__min_df': 1, 'tfidf__ngram_range': (1, 2), 'tfidf__sublinear_tf': True}
# Best CV score: 0.951420598118603
# Classification report:
#               precision    recall  f1-score   support
#
#           -1       0.78      0.47      0.59      7523
#            1       0.93      0.98      0.95     49890
#
#     accuracy                           0.91     57413
#    macro avg       0.85      0.73      0.77     57413
# weighted avg       0.91      0.91      0.90     57413

# %% [markdown]
# # Word2Vec weighted by TF-IDF

# %%
import gensim.downloader as api
glove_embeddings = api.load("glove-twitter-200")

# {'classifier__C': 1, 'tfidf__max_df': 0.9, 'tfidf__min_df': 5, 'tfidf__ngram_range': (1, 2), 'tfidf__sublinear_tf': True}

# %%
def preprocess_for_glove(text,glove, stop_words=None, stemmer=None):
    """
    Transform text to remove unwanted bits
    """

    # Make lowercase
    text = text.lower()

    # Remove punctuation and whitespaces
    punctuation = string.punctuation + string.whitespace
    text = text.translate(str.maketrans(punctuation, " " * len(punctuation)))

    # Remove numbers
    text = re.sub(r"\d", " ", text)

    # Remove extra spaces
    text = re.sub(r"\s+", " ", text)

    # Tokenize
    tokens = text.split()
    
    tokens = [token for token in tokens if token in glove]

    # Remove stop words
    if stop_words is not None:
        tokens = [token for token in tokens if token not in stop_words]

    # Stem
    if stemmer is not None:
        tokens = [stemmer.stem(token) for token in tokens]

    text = " ".join(tokens)

    return text

# %%
from functools import partial
from sklearn.preprocessing import normalize

tf_idf = TfidfVectorizer(preprocessor=partial(preprocess_for_glove, glove = glove_embeddings))

X_tf_idf = tf_idf.fit_transform(x_movies)

word_embed = np.empty((X_tf_idf.shape[1], glove_embeddings.vector_size))
for i, token in enumerate(tf_idf.get_feature_names_out()):
    word_embed[i,:] = glove_embeddings.get_vector(token)

# X_train = X_tf_idf.toarray() @ word_embed
X_train = (X_tf_idf.toarray()>0)@ word_embed
# X_train = normalize(X_tf_idf, "l1", axis=1) @ word_embed
y_train = y_movies

# %%
SCORE = "f1"
# 1 is expected to be minority class, need to balance classes where possible
ratio = np.sum(y_train == 0) / np.sum(y_train == 1)

# # Preprocess ========================
# preprocess_param_grid = {
#     "tfidf__ngram_range": [(1,2)],#[(1, 1), (1, 2)],
#     "tfidf__min_df": [2],#[1, 2, 5],
#     "tfidf__max_df": [0.9],#[0.9, 1.0],
#     "tfidf__sublinear_tf": [True]#[False, True],
# }

# Linear SVM =================================================================================

svm_model = Pipeline([
    # ("tfidf", TfidfVectorizer(preprocessor=preprocess)),
    ("svm", SVC(class_weight='balanced'))
    ])

svm_param_grid = [
    {
        # **preprocess_param_grid,
        "svm__kernel": ["linear"],
        "svm__C": [0.01, 0.1, 1, 10]
    },
    {
        # **preprocess_param_grid,
        "svm__kernel": ["poly"],
        "svm__C": [0.1, 1, 10],
        "svm__degree": [2, 3, 4],
        "svm__gamma": ["scale", "auto"]
    },
    {
        # **preprocess_param_grid,
        "svm__kernel": ["rbf"],
        "svm__C": [0.1, 1, 10],
        "svm__gamma": ["scale", "auto"]
    }
]

svm_cv = GridSearchCV(svm_model, svm_param_grid, cv=5, scoring=SCORE, n_jobs=-1, verbose=3)

# Random Forest =============================================================================
rf_model = Pipeline(steps=[
    # ("tfidf", TfidfVectorizer(preprocessor=preprocess)),
    ("rf", RandomForestClassifier(class_weight='balanced',n_estimators=300))
])
rf_param_grid = {
    # **preprocess_param_grid,
    "rf__n_estimators": [100, 300, 500],
    "rf__max_depth": [None, 10, 20],
    "rf__min_samples_split": [2, 5],
    "rf__min_samples_leaf": [1, 2]
}

rf_cv = GridSearchCV(rf_model, rf_param_grid, cv=5, scoring=SCORE, n_jobs=-1, verbose=3)

# XGBoost ==========================================================================


xgb_model = Pipeline(steps=[
    # ("tfidf", TfidfVectorizer(preprocessor=preprocess)),
    ("xgb", XGBClassifier(
        objective="binary:logistic",
        eval_metric="auc",
        # use_label_encoder=False,
        # scale_pos_weight= ratio # NOTE: may need for presidents
    ))
])

xgb_param_grid = {
    # **preprocess_param_grid,
    "xgb__n_estimators": [100, 300],
    "xgb__max_depth": [3, 5],
    "xgb__learning_rate": [0.01, 0.05, 0.1],
    "xgb__subsample": [0.8, 1.0],
    "xgb__colsample_bytree": [0.8, 1.0], 
    "xgb__gamma": [0, 0.1]  
}

xgb_cv = GridSearchCV(xgb_model, xgb_param_grid, cv=5, scoring=SCORE, n_jobs=-1, verbose=3)

# All models =======================================================================================
model_cvs = (
    xgb_cv,
    svm_cv,
    rf_cv,
    
)

full_names = {
    "svm": "Support Vector Machine",
    "xgb" : "XGBoost",
    "rf": "Random Forest",
    
}
# Out:
# /var/folders/hr/c9xk46kd0t3c2nlgs6zkg2_h0000gn/T/ipykernel_38096/2213303614.py:3: RuntimeWarning: invalid value encountered in scalar divide
#   ratio = np.sum(y_train == 0) / np.sum(y_train == 1)

# %%
RUN_TUNING = True
MODEL_PATH = "../models/"
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
if RUN_TUNING:
    summary_df = pd.DataFrame()
    models = {}
    for model_cv in model_cvs:
        model_cv.fit(X_train, y_train)
        # NOTE: best estimator is trained on the whole train dataset
        model = model_cv.best_estimator_ 
        model_name = list(model.named_steps.keys())[0]
        models[model_name] = model
        cv_df = pd.DataFrame(model_cv.cv_results_)[['params', 'mean_test_score', 'std_test_score']]
        cv_df = cv_df[cv_df["mean_test_score"] == cv_df["mean_test_score"].max() ]

        model.fit(X_train, y_train)
        
        print(model_name, ":::::::::::::::::::::::::::::::::::")
        
        print(f"Best parameters: {model_cv.best_params_}")
        print(f"Best CV score: {model_cv.best_score_}")

        y_pred = cross_val_predict(model, X_train, y_train, cv=cv)

        print("Classification report:")
        print(classification_report(y_train, y_pred))

        summary_row = pd.DataFrame([{"model" : model_name}])
        summary_row.reset_index(drop=True, inplace=True)
        cv_df.reset_index(drop=True, inplace=True)
        summary_row = pd.concat([summary_row, cv_df], axis=1)
        summary_df = pd.concat([summary_df, summary_row], axis=0)
        
    summary_df.reset_index(drop=True, inplace=True)
    with open(MODEL_PATH + "summary_df.pkl","wb") as f:
            pickle.dump(summary_df,f)
    with open(MODEL_PATH + "models.pkl","wb") as f:
        pickle.dump(models,f)
else:
    with open(MODEL_PATH + "summary_df.pkl","rb") as f:
        summary_df =pickle.load(f)
    with open(MODEL_PATH + "models.pkl","rb") as f:
        models =pickle.load(f)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV 2/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.726 total time=   0.5s
# [CV 1/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.730 total time=   0.5s
# [CV 4/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.759 total time=   0.5s
# [CV 4/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.757 total time=   0.6s
# [CV 5/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.729 total time=   0.6s
# [CV 3/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.687 total time=   0.6s
# [CV 2/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.744 total time=   0.6s
# [CV 1/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.726 total time=   0.5s
# [CV 5/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.713 total time=   0.6s
# [CV 3/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.696 total time=   0.5s
# [CV 4/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.759 total time=   1.4s
# [CV 1/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.742 total time=   1.5s
# [CV 2/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.731 total time=   1.5s
# [CV 2/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.743 total time=   1.5s
# [CV 5/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.741 total time=   1.5s
# [CV 1/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.730 total time=   1.6s
# [CV 4/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.770 total time=   1.5s
# [CV 3/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.716 total time=   1.6s
# [CV 3/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.715 total time=   1.7s
# [CV 5/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.745 total time=   1.6s
# [CV 1/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.749 total time=   1.7s
# [CV 3/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.723 total time=   1.7s
# [CV 4/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.755 total time=   1.8s
# [CV 2/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.747 total time=   1.8s
# [CV 2/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.734 total time=   1.8s
# [CV 5/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.731 total time=   1.8s
# [CV 1/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.734 total time=   1.8s
# [CV 3/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.691 total time=   1.9s
# [CV 4/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.739 total time=   1.8s
# [CV 5/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.722 total time=   1.7s
# [CV 1/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.762 total time=   4.8s
# [CV 2/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.754 total time=   4.6s
# [CV 1/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.751 total time=   4.6s
# [CV 3/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.740 total time=   4.7s
# [CV 4/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.777 total time=   4.7s
# [CV 5/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.757 total time=   4.7s
# [CV 4/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.768 total time=   4.7s
# [CV 2/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.743 total time=   4.9s
# [CV 1/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.781 total time=   0.5s
# [CV 3/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.737 total time=   5.0s
# [CV 4/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.784 total time=   0.5s
# [CV 2/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.744 total time=   0.6s
# [CV 3/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.724 total time=   0.6s
# [CV 5/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.01, xgb__max_depth=5, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.744 total time=   4.8s
# [CV 5/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.770 total time=   0.6s
# [CV 1/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.768 total time=   0.5s
# [CV 2/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.746 total time=   0.5s
# [CV 3/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.732 total time=   0.6s
# [CV 4/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.769 total time=   0.5s
# [CV 5/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.756 total time=   0.5s
# [CV 1/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.794 total time=   1.5s
# [CV 4/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.775 total time=   1.4s
# [CV 2/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.749 total time=   1.5s
# [CV 3/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.759 total time=   1.4s
# [CV 5/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=0.8;, score=0.765 total time=   1.4s
# [CV 1/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.787 total time=   1.4s
# [CV 2/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.749 total time=   1.6s
# [CV 3/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.744 total time=   1.6s
# [CV 4/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.778 total time=   1.6s
# [CV 5/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=3, xgb__n_estimators=300, xgb__subsample=1.0;, score=0.777 total time=   1.5s
# [CV 4/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.765 total time=   1.6s
# [CV 1/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.789 total time=   1.6s
# [CV 2/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.754 total time=   1.6s
# [CV 3/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.715 total time=   1.7s
# [CV 5/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=0.8;, score=0.754 total time=   1.7s
# [CV 1/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.753 total time=   1.8s
# [CV 2/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.743 total time=   1.8s
# [CV 3/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.748 total time=   1.9s
# [CV 4/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.777 total time=   1.9s
# [CV 5/5] END xgb__colsample_bytree=0.8, xgb__gamma=0, xgb__learning_rate=0.05, xgb__max_depth=5, xgb__n_estimators=100, xgb__subsample=1.0;, score=0.762 total time=   1.8s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[152], line 8
#       6 models = {}
#       7 for model_cv in model_cvs:
# ----> 8     model_cv.fit(X_train, y_train)
#       9     # NOTE: best estimator is trained on the whole train dataset
#      10     model = model_cv.best_estimator_
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1053, in BaseSearchCV.fit(self, X, y, **params)
#    1047     results = self._format_results(
#    1048         all_candidate_params, n_splits, all_out, all_more_results
#    1049     )
#    1051     return results
# -> 1053 self._run_search(evaluate_candidates)
#    1055 # multimetric is determined here because in the case of a callable
#    1056 # self.scoring the return type is only known after calling
#    1057 first_test_score = all_out[0]["test_scores"]
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1612, in GridSearchCV._run_search(self, evaluate_candidates)
#    1610 def _run_search(self, evaluate_candidates):
#    1611     """Search all candidates in param_grid"""
# -> 1612     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/model_selection/_search.py:999, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     991 if self.verbose > 0:
#     992     print(
#     993         "Fitting {0} folds for each of {1} candidates,"
#     994         " totalling {2} fits".format(
#     995             n_splits, n_candidates, n_candidates * n_splits
#     996         )
#     997     )
# --> 999 out = parallel(
#    1000     delayed(_fit_and_score)(
#    1001         clone(base_estimator),
#    1002         X,
#    1003         y,
#    1004         train=train,
#    1005         test=test,
#    1006         parameters=parameters,
#    1007         split_progress=(split_idx, n_splits),
#    1008         candidate_progress=(cand_idx, n_candidates),
#    1009         **fit_and_score_kwargs,
#    1010     )
#    1011     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#    1012         enumerate(candidate_params),
#    1013         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#    1014     )
#    1015 )
#    1017 if len(out) < 1:
#    1018     raise ValueError(
#    1019         "No fits were performed. "
#    1020         "Was the CV iterator empty? "
#    1021         "Were there no candidates?"
#    1022     )
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/joblib/parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %% [markdown]
# # Other Classifiers

# %%
X_train = x_movies
y_train = np.array(y_movies)

# %%
SCORE = "f1"
# 1 is expected to be minority class, need to balance classes where possible
ratio = np.sum(y_train == 0) / np.sum(y_train == 1)

# Preprocess ========================
preprocess_param_grid = {
    "tfidf__ngram_range": [(1,2)],#[(1, 1), (1, 2)],
    "tfidf__min_df": [2],#[1, 2, 5],
    "tfidf__max_df": [0.9],#[0.9, 1.0],
    "tfidf__sublinear_tf": [True]#[False, True],
}

# Linear SVM =================================================================================

svm_model = Pipeline([
    ("tfidf", TfidfVectorizer(preprocessor=preprocess)),
    ("svm", SVC(class_weight='balanced'))
    ])

svm_param_grid = [
    {
        **preprocess_param_grid,
        "svm__kernel": ["linear"],
        "svm__C": [0.01, 0.1, 1, 10]
    },
    {
        **preprocess_param_grid,
        "svm__kernel": ["poly"],
        "svm__C": [0.1, 1, 10],
        "svm__degree": [2, 3, 4],
        "svm__gamma": ["scale", "auto"]
    },
    {
        **preprocess_param_grid,
        "svm__kernel": ["rbf"],
        "svm__C": [0.1, 1, 10],
        "svm__gamma": ["scale", "auto"]
    }
]

svm_cv = GridSearchCV(svm_model, svm_param_grid, cv=5, scoring=SCORE, n_jobs=-1, verbose=3)

# Random Forest =============================================================================
rf_model = Pipeline(steps=[
    ("tfidf", TfidfVectorizer(preprocessor=preprocess)),
    ("rf", RandomForestClassifier(class_weight='balanced',n_estimators=300))
])
rf_param_grid = {
    **preprocess_param_grid,
    "rf__n_estimators": [100, 300, 500],
    "rf__max_depth": [None, 10, 20],
    "rf__min_samples_split": [2, 5],
    "rf__min_samples_leaf": [1, 2]
}

rf_cv = GridSearchCV(rf_model, rf_param_grid, cv=5, scoring=SCORE, n_jobs=-1, verbose=3)

# XGBoost ==========================================================================


xgb_model = Pipeline(steps=[
    ("tfidf", TfidfVectorizer(preprocessor=preprocess)),
    ("xgb", XGBClassifier(
        objective="binary:logistic",
        eval_metric="auc",
        # use_label_encoder=False,
        # scale_pos_weight= ratio # NOTE: may need for presidents
    ))
])

xgb_param_grid = {
    **preprocess_param_grid,
    "xgb__n_estimators": [100, 300],
    "xgb__max_depth": [3, 5],
    "xgb__learning_rate": [0.01, 0.05, 0.1],
    "xgb__subsample": [0.8, 1.0],
    "xgb__colsample_bytree": [0.8, 1.0], 
    "xgb__gamma": [0, 0.1]  
}

xgb_cv = GridSearchCV(xgb_model, xgb_param_grid, cv=5, scoring=SCORE, n_jobs=-1, verbose=3)

# All models =======================================================================================
model_cvs = (
    rf_cv,
    xgb_cv,
    # svm_cv,
    
)

full_names = {
    "xgb" : "XGBoost",
    # "svm": "Support Vector Machine",
    "rf": "Random Forest",
    
}

# %%
RUN_TUNING = True
MODEL_PATH = "../models/"
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
if RUN_TUNING:
    summary_df = pd.DataFrame()
    models = {}
    for model_cv in model_cvs:
        model_cv.fit(X_train, y_train)
        # NOTE: best estimator is trained on the whole train dataset
        model = model_cv.best_estimator_ 
        model_name = list(model.named_steps.keys())[1]
        models[model_name] = model
        cv_df = pd.DataFrame(model_cv.cv_results_)[['params', 'mean_test_score', 'std_test_score']]
        cv_df = cv_df[cv_df["mean_test_score"] == cv_df["mean_test_score"].max() ]

        model.fit(X_train, y_train)
        
        print(model_name, ":::::::::::::::::::::::::::::::::::")
        
        print(f"Best parameters: {model_cv.best_params_}")
        print(f"Best CV score: {model_cv.best_score_}")

        y_pred = cross_val_predict(model, X_train, y_train, cv=cv)

        print("Classification report:")
        print(classification_report(y_train, y_pred))

        summary_row = pd.DataFrame([{"model" : list(model.named_steps.keys())[1]}])
        summary_row.reset_index(drop=True, inplace=True)
        cv_df.reset_index(drop=True, inplace=True)
        summary_row = pd.concat([summary_row, cv_df], axis=1)
        summary_df = pd.concat([summary_df, summary_row], axis=0)
        
    summary_df.reset_index(drop=True, inplace=True)
    with open(MODEL_PATH + "summary_df.pkl","wb") as f:
            pickle.dump(summary_df,f)
    with open(MODEL_PATH + "models.pkl","wb") as f:
        pickle.dump(models,f)
else:
    with open(MODEL_PATH + "summary_df.pkl","rb") as f:
        summary_df =pickle.load(f)
    with open(MODEL_PATH + "models.pkl","rb") as f:
        models =pickle.load(f)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 2/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.725 total time=   4.8s
# [CV 4/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.754 total time=   4.9s
# [CV 3/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.773 total time=   4.9s
# [CV 1/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.768 total time=   5.2s
# [CV 5/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.788 total time=   5.2s
# [CV 2/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.815 total time=   9.3s
# [CV 5/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.811 total time=   9.5s
# [CV 3/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.761 total time=   9.6s
# [CV 4/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.794 total time=   9.7s
# [CV 1/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.816 total time=   9.8s
# [CV 1/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.778 total time=   4.6s
# [CV 3/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.761 total time=   4.5s
# [CV 4/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.777 total time=   4.4s
# [CV 2/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.775 total time=   4.6s
# [CV 5/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.824 total time=   4.6s
# [CV 2/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.808 total time=  13.7s
# [CV 5/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.826 total time=  13.6s
# [CV 1/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.814 total time=  14.0s
# [CV 3/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.797 total time=  14.4s
# [CV 4/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.788 total time=  14.4s
# [CV 3/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.791 total time=   9.3s
# [CV 1/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.780 total time=   9.5s
# [CV 2/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.803 total time=   9.5s
# [CV 5/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.797 total time=   9.3s
# [CV 4/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.798 total time=   9.5s
# [CV 1/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.756 total time=   4.7s
# [CV 2/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.806 total time=   4.8s
# [CV 3/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.757 total time=   4.9s
# [CV 4/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.764 total time=   5.2s
# [CV 5/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.802 total time=   5.1s
# [CV 2/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.790 total time=  15.1s
# [CV 3/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.779 total time=  15.0s
# [CV 1/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.787 total time=  15.6s
# [CV 5/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.804 total time=  15.1s
# [CV 4/5] END rf__max_depth=None, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.784 total time=  15.5s
# [CV 3/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.768 total time=  10.2s
# [CV 2/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.805 total time=  10.7s
# [CV 1/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.812 total time=  11.0s
# [CV 4/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.796 total time=  10.3s
# [CV 5/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.844 total time=  10.9s
# [CV 2/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.766 total time=   4.7s
# [CV 3/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.764 total time=   4.9s
# [CV 1/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.803 total time=   5.3s
# [CV 4/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.791 total time=   4.9s
# [CV 5/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.788 total time=   4.9s
# [CV 1/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.843 total time=  14.7s
# [CV 2/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.820 total time=  14.7s
# [CV 3/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.818 total time=  14.5s
# [CV 5/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.831 total time=  14.3s
# [CV 4/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.791 total time=  14.5s
# [CV 1/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.807 total time=   9.3s
# [CV 4/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.817 total time=   9.1s
# [CV 2/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.812 total time=   9.4s
# [CV 3/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.800 total time=   9.5s
# [CV 5/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.829 total time=   9.1s
# [CV 1/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.805 total time=   3.4s
# [CV 3/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.747 total time=   3.3s
# [CV 2/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.792 total time=   3.4s
# [CV 4/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.802 total time=   3.4s
# [CV 5/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.811 total time=   3.3s
# [CV 2/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.838 total time=  12.9s
# [CV 1/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.817 total time=   4.9s
# [CV 1/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.813 total time=  13.3s
# [CV 3/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.796 total time=   4.8s
# [CV 2/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.820 total time=   5.0s
# [CV 3/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.798 total time=  13.2s
# [CV 4/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.804 total time=  13.0s
# [CV 4/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.794 total time=   5.0s
# [CV 5/5] END rf__max_depth=None, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.849 total time=  13.1s
# [CV 5/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.834 total time=   4.9s
# [CV 1/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.802 total time=   3.3s
# [CV 2/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.768 total time=   3.4s
# [CV 4/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.780 total time=   3.1s
# [CV 3/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.767 total time=   3.4s
# [CV 5/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.821 total time=   3.4s
# [CV 1/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.835 total time=   6.3s
# [CV 2/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.797 total time=   6.3s
# [CV 3/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.804 total time=   6.4s
# [CV 5/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.828 total time=   6.3s
# [CV 4/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.817 total time=   6.4s
# [CV 3/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.811 total time=   5.0s
# [CV 1/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.797 total time=   5.4s
# [CV 4/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.800 total time=   5.1s
# [CV 2/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.782 total time=   5.2s
# [CV 5/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.822 total time=   5.2s
# [CV 1/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.772 total time=   3.9s
# [CV 3/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.768 total time=   4.0s
# [CV 4/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.773 total time=   4.0s
# [CV 2/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.788 total time=   4.1s
# [CV 1/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.801 total time=   7.0s
# [CV 3/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.789 total time=   7.2s
# [CV 2/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.813 total time=   7.4s
# [CV 5/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.843 total time=   7.4s
# [CV 4/5] END rf__max_depth=10, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.802 total time=   7.5s
# [CV 5/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.804 total time=   3.9s
# [CV 1/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.803 total time=   5.5s
# [CV 2/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.807 total time=   5.7s
# [CV 4/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.815 total time=   5.5s
# [CV 3/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.767 total time=   5.7s
# [CV 5/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.817 total time=   5.6s
# [CV 2/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.816 total time=   6.8s
# [CV 1/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.813 total time=   7.0s
# [CV 3/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.805 total time=   6.8s
# [CV 4/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.807 total time=   6.8s
# [CV 5/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.822 total time=   7.0s
# [CV 2/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.786 total time=   3.4s
# [CV 3/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.723 total time=   3.4s
# [CV 1/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.752 total time=   3.9s
# [CV 4/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.778 total time=   3.4s
# [CV 5/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.805 total time=   3.4s
# [CV 1/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.815 total time=   4.9s
# [CV 2/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.793 total time=   5.1s
# [CV 3/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.806 total time=   5.0s
# [CV 4/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.826 total time=   5.0s
# [CV 5/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.822 total time=   5.0s
# [CV 1/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.824 total time=   6.5s
# [CV 4/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.792 total time=   6.4s
# [CV 2/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.820 total time=   6.5s
# [CV 3/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.774 total time=   6.8s
# [CV 5/5] END rf__max_depth=10, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.823 total time=   6.6s
# [CV 1/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.772 total time=   4.5s
# [CV 3/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.745 total time=   4.4s
# [CV 2/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.745 total time=   4.5s
# [CV 4/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.765 total time=   4.4s
# [CV 5/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.800 total time=   4.5s
# [CV 1/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.798 total time=   6.9s
# [CV 2/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.803 total time=   7.2s
# [CV 3/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.798 total time=   7.3s
# [CV 4/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.788 total time=   7.3s
# [CV 5/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.816 total time=   7.1s
# [CV 1/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.775 total time=   3.9s
# [CV 2/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.761 total time=   3.8s
# [CV 1/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.811 total time=   9.9s
# [CV 2/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.802 total time=   9.7s
# [CV 4/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.760 total time=   3.6s
# [CV 3/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.787 total time=   9.8s
# [CV 3/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.768 total time=   3.9s
# [CV 4/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.805 total time=   9.6s
# [CV 5/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.826 total time=   3.9s
# [CV 5/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.805 total time=   9.7s
# [CV 1/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.800 total time=   6.4s
# [CV 3/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.792 total time=   6.3s
# [CV 2/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.811 total time=   6.5s
# [CV 4/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.817 total time=   6.4s
# [CV 5/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.849 total time=   6.5s
# [CV 2/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.807 total time=   8.8s
# [CV 3/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.799 total time=   9.2s
# [CV 1/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.804 total time=   9.4s
# [CV 4/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.806 total time=   9.2s
# [CV 1/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.806 total time=   3.8s
# [CV 5/5] END rf__max_depth=20, rf__min_samples_leaf=1, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.833 total time=   9.2s
# [CV 2/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.755 total time=   3.8s
# [CV 3/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.782 total time=   3.7s
# [CV 4/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.784 total time=   3.8s
# [CV 5/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.805 total time=   3.9s
# [CV 1/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.812 total time=   6.4s
# [CV 2/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.835 total time=   6.5s
# [CV 3/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.800 total time=   6.5s
# [CV 4/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.815 total time=   6.5s
# [CV 5/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.822 total time=   6.4s
# [CV 4/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.810 total time=   8.9s
# [CV 1/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.778 total time=   3.7s
# [CV 1/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.815 total time=   9.1s
# [CV 3/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.814 total time=   9.0s
# [CV 2/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.818 total time=   9.2s
# [CV 5/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=2, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.806 total time=   9.1s
# [CV 2/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.780 total time=   3.6s
# [CV 4/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.779 total time=   3.6s
# [CV 3/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.792 total time=   3.9s
# [CV 5/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=100, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.811 total time=   3.8s
# [CV 2/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.820 total time=   6.1s
# [CV 5/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.825 total time=   6.1s
# [CV 1/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.814 total time=   6.4s
# [CV 3/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.792 total time=   6.4s
# [CV 4/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=300, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.786 total time=   6.7s
# [CV 2/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.833 total time=   7.9s
# [CV 1/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.818 total time=   8.2s
# [CV 4/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.809 total time=   7.8s
# [CV 3/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.796 total time=   7.9s
# [CV 5/5] END rf__max_depth=20, rf__min_samples_leaf=2, rf__min_samples_split=5, rf__n_estimators=500, tfidf__max_df=0.9, tfidf__min_df=2, tfidf__ngram_range=(1, 2), tfidf__sublinear_tf=True;, score=0.822 total time=   7.4s
# rf :::::::::::::::::::::::::::::::::::
# Best parameters: {'rf__max_depth': None, 'rf__min_samples_leaf': 2, 'rf__min_samples_split': 2, 'rf__n_estimators': 500, 'tfidf__max_df': 0.9, 'tfidf__min_df': 2, 'tfidf__ngram_range': (1, 2), 'tfidf__sublinear_tf': True}
# Best CV score: 0.8205985138650794
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[51], line 23
#      20 print(f"Best parameters: {model_cv.best_params_}")
#      21 print(f"Best CV score: {model_cv.best_score_}")
# ---> 23 y_pred = cross_val_predict(model, X_train, y_train, cv=cv)
#      25 print("Classification report:")
#      26 print(classification_report(y_train, y_pred))
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:1211, in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, params, pre_dispatch, method)
#    1208 # We clone the estimator to make sure that all the folds are
#    1209 # independent, and that it is pickle-able.
#    1210 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# -> 1211 predictions = parallel(
#    1212     delayed(_fit_and_predict)(
#    1213         clone(estimator),
#    1214         X,
#    1215         y,
#    1216         train,
#    1217         test,
#    1218         routed_params.estimator.fit,
#    1219         method,
#    1220     )
#    1221     for train, test in splits
#    1222 )
#    1224 inv_test_indices = np.empty(len(test_indices), dtype=int)
#    1225 inv_test_indices[test_indices] = np.arange(len(test_indices))
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/model_selection/_validation.py:1299, in _fit_and_predict(estimator, X, y, train, test, fit_params, method)
#    1297     estimator.fit(X_train, **fit_params)
#    1298 else:
# -> 1299     estimator.fit(X_train, y_train, **fit_params)
#    1300 func = getattr(estimator, method)
#    1301 predictions = func(X_test)
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/pipeline.py:621, in Pipeline.fit(self, X, y, **params)
#     615     if self._final_estimator != "passthrough":
#     616         last_step_params = self._get_metadata_for_step(
#     617             step_idx=len(self) - 1,
#     618             step_params=routed_params[self.steps[-1][0]],
#     619             all_params=params,
#     620         )
# --> 621         self._final_estimator.fit(Xt, y, **last_step_params["fit"])
#     623 return self
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/ensemble/_forest.py:486, in BaseForest.fit(self, X, y, sample_weight)
#     475 trees = [
#     476     self._make_estimator(append=False, random_state=random_state)
#     477     for i in range(n_more_estimators)
#     478 ]
#     480 # Parallel loop: we prefer the threading backend as the Cython code
#     481 # for fitting the trees is internally releasing the Python GIL
#     482 # making threading more efficient than multiprocessing in
#     483 # that case. However, for joblib 0.12+ we respect any
#     484 # parallel_backend contexts set at a higher level,
#     485 # since correctness does not rely on using threads.
# --> 486 trees = Parallel(
#     487     n_jobs=self.n_jobs,
#     488     verbose=self.verbose,
#     489     prefer="threads",
#     490 )(
#     491     delayed(_parallel_build_trees)(
#     492         t,
#     493         self.bootstrap,
#     494         X,
#     495         y,
#     496         sample_weight,
#     497         i,
#     498         len(trees),
#     499         verbose=self.verbose,
#     500         class_weight=self.class_weight,
#     501         n_samples_bootstrap=n_samples_bootstrap,
#     502         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     503     )
#     504     for i, t in enumerate(trees)
#     505 )
#     507 # Collect newly grown trees
#     508 self.estimators_.extend(trees)
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/joblib/parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/joblib/parallel.py:1914, in Parallel._get_sequential_output(self, iterable)
#    1912 self.n_dispatched_batches += 1
#    1913 self.n_dispatched_tasks += 1
# -> 1914 res = func(*args, **kwargs)
#    1915 self.n_completed_tasks += 1
#    1916 self.print_progress()
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/utils/parallel.py:184, in _FuncWrapper.__call__(self, *args, **kwargs)
#     180                 this_warning_filter_dict[special_key] = this_value.pattern
#     182         warnings.filterwarnings(**this_warning_filter_dict, append=True)
# --> 184 return self.function(*args, **kwargs)
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/ensemble/_forest.py:188, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap, missing_values_in_feature_mask)
#     185     elif class_weight == "balanced_subsample":
#     186         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 188     tree._fit(
#     189         X,
#     190         y,
#     191         sample_weight=curr_sample_weight,
#     192         check_input=False,
#     193         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     194     )
#     195 else:
#     196     tree._fit(
#     197         X,
#     198         y,
#    (...)    201         missing_values_in_feature_mask=missing_values_in_feature_mask,
#     202     )
#
# File ~/Documents/University/Master-MIND/nlp-document-classification/.venv/lib/python3.13/site-packages/sklearn/tree/_classes.py:475, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     464 else:
#     465     builder = BestFirstTreeBuilder(
#     466         splitter,
#     467         min_samples_split,
#    (...)    472         self.min_impurity_decrease,
#     473     )
# --> 475 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     477 if self.n_outputs_ == 1 and is_classifier(self):
#     478     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:
